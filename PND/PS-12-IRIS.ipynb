# %%
"""
Problem Statement No. 12 
Scan the Iris dataset and give the inference as:  
1. List down the features and their types (e.g., numeric, nominal) available in the dataset. 
2. Create a histogram for each feature in the dataset to illustrate the feature distributions.  
3. Create a boxplot for each feature in the dataset. 
4. Compare distributions and identify outliers. 
"""

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.drop('Id',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Histogram</h1>

# %%
plt.hist(df['SepalLengthCm'],bins=10,color='blue',edgecolor='black')
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.title('Histogram of SepalLength in Centimeter')
plt.show()

# %%
plt.hist(df['PetalLengthCm'],bins=10,color='pink',edgecolor='red')
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.title('Histogram of Petal Length in Centimeter')
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Length in Centimeter')

# %%
plt.hist(df['SepalWidthCm'],bins=10,color='blue',edgecolor='black')
# Out:
# (array([ 4.,  7., 22., 24., 38., 31.,  9., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['PetalWidthCm'],bins=10,color='black',edgecolor='white')
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
fig , axis = plt.subplots(nrows = 2 ,ncols = 2 , figsize = (12,8))
df['PetalWidthCm'].plot(kind='hist',bins=10,color='pink',edgecolor='red',ax = axis[0,0])
axis[0,0].set_xlabel('Length in CM')
axis[0,0].set_ylabel('Frequency')
axis[0,0].set_title('Petal Width in CM')

df['SepalWidthCm'].plot(kind='hist',bins=10,color='black',edgecolor='white',ax= axis[0,1])
axis[0,1].set_xlabel('Length in CM')
axis[0,1].set_ylabel('Frequency')
axis[0,1].set_title('Sepal Width in CM')

df['SepalLengthCm'].plot(kind = 'hist',bins=10,color='blue',edgecolor='white',ax=axis[1,0])
axis[1,0].set_xlabel('Length in CM')
axis[1,0].set_ylabel('Frequency')
axis[1,0].set_title('Sepal Length in CM')

df['PetalLengthCm'].plot(kind = 'hist',bins=10,color='red',edgecolor='white',ax=axis[1,1])
axis[1,1].set_xlabel('Length in CM')
axis[1,1].set_ylabel('Frequency')
axis[1,1].set_title('Petal Length in CM')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Box Plot</h1>

# %%
plt.boxplot(df['PetalWidthCm'])
plt.xlabel('')
plt.ylabel('Length in CM')
plt.title('Boxplot of Petal width')
plt.show()

# %%
plt.boxplot(df['PetalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27e71bb9c30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27e71bba1d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27e71bb88b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27e71bba770>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27e71bbaa40>],
#  'means': []}

# %%
plt.boxplot(df['SepalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27e718ef880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27e718ecfd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27e718eea70>],
#  'medians': [<matplotlib.lines.Line2D at 0x27e718ed960>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27e718edab0>],
#  'means': []}

# %%
plt.boxplot(df['SepalWidthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27e71845a20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27e71847640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27e71844c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x27e71844af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27e71845270>],
#  'means': []}

# %%
plt.boxplot([df['PetalLengthCm'],df['PetalWidthCm'],df['SepalLengthCm'],df['SepalWidthCm']])
plt.xticks([1, 2, 3, 4], ['PetalLengthCm', 'PetalWidthCm', 'SepalLengthCm', 'SepalWidthCm'])
plt.ylabel('Value')
plt.show()
